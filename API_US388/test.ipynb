# %%
import boto3
from io import BytesIO
from moviepy.editor import ImageClip

# Initialize the S3 client
session = boto3.Session(region_name='eu-west-1')

s3 = session.client('s3',aws_access_key_id="AKIAUJXLE2HEOGWEMCEX",aws_secret_access_key="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")

# %%
from datalake import put_image_in_s3

audio_path="music/warrior_medium-192841.mp3"
with open(audio_path, 'rb') as f:
    audio_data = f.read()
put_image_in_s3(audio_data,'soulchain-dev1-output-video',f'background_music/warrior_medium-192841.mp3')



# with open("default_video.mp4", 'rb') as f:
#     video_data = f.read()

# put_image_in_s3(video_data,'soulchain-dev1-output-video',f'datalake_media/default_video.mp4')
# Out:
# Media uploaded successfully to S3

# %%
import tempfile
from moviepy.editor import ImageClip, concatenate_videoclips, AudioFileClip
from PIL import Image
import numpy as np

try:
    # Fetch image from S3
    response_image = s3.get_object(Bucket='soulchain-dev1-output-video', Key="datalake_media/image-abdominal-pain-2493327_150.jpg-3aef656c-228a-42ed-bb7c-471369ad11ce")
    image_data = response_image['Body'].read()
except Exception as e:
    print("Error reading image from S3:", e)

image_stream = BytesIO(image_data)

# Convert image to numpy array
image = Image.open(image_stream)
image_np = np.array(image)

# Create image clip
image_clip = ImageClip(image_np, duration=10)

try:
    # Fetch audio from S3
    response_audio = s3.get_object(Bucket='soulchain-dev1-output-video', Key="generated_videos/video1/audio1")
    audio_data = response_audio['Body'].read()
except Exception as e:
    print("Error reading audio from S3:", e)

# Create a temporary file to write audio data
with tempfile.NamedTemporaryFile(suffix='.mp3') as temp_file:
    temp_file.write(audio_data)
    temp_file.seek(0)  # Reset file pointer to beginning
    
    audio_clip = AudioFileClip(temp_file.name)

image_clip = image_clip.set_duration(audio_clip.duration)

final_clip = concatenate_videoclips([image_clip.set_audio(audio_clip)])

with tempfile.NamedTemporaryFile(suffix='.mp4') as temp_output_file:
    temp_output_file_path = temp_output_file.name
    final_clip.write_videofile(temp_output_file_path, fps=24)

    # Upload final video file to S3
    try:
        s3.upload_file(temp_output_file_path, 'soulchain-dev1-output-video', 'video')
        print("Successfully uploaded the final video to S3.")
    except Exception as e:
        print("Error uploading final video to S3:", e)
# Out:
# Moviepy - Building video /var/folders/ys/s5c8y6vx2n95hnjtr5vs5h000000gn/T/tmpxfgn8m9t.mp4.
# MoviePy - Writing audio in tmpxfgn8m9tTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /var/folders/ys/s5c8y6vx2n95hnjtr5vs5h000000gn/T/tmpxfgn8m9t.mp4
# Moviepy - Done !
# Moviepy - video ready /var/folders/ys/s5c8y6vx2n95hnjtr5vs5h000000gn/T/tmpxfgn8m9t.mp4
# Successfully uploaded the final video to S3.

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips
import tempfile

try:
    response = s3.get_object(Bucket='soulchain-dev1-output-video', Key="video-ec0c97a6-a5d2-4452-8db3-416f4001c0f2")
    video_data = response['Body'].read()
except Exception as e:
    print("Error reading video from S3:", e)
    
with tempfile.NamedTemporaryFile(suffix='.mp4') as temp_file:
    temp_file.write(video_data)
    temp_file.seek(0)  
    
    video_clip = VideoFileClip(temp_file.name)

video_duration = video_clip.duration

repeated_video_clips = [video_clip]

final_video_clip = concatenate_videoclips(repeated_video_clips)

output_file_path = "output_video.mp4"
final_video_clip.write_videofile(output_file_path, fps=24)
# Out:
# Moviepy - Building video output_video.mp4.
# MoviePy - Writing audio in output_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video output_video.mp4
# Moviepy - Done !
# Moviepy - video ready output_video.mp4

# %%
from datalake import upload_file_to_s3

output_bucket = "soulchain-dev1-output-video"
s3_key = f"generated_videos/video_user1/audio4"
file_path="audio4"
upload_file_to_s3(file_path,output_bucket,s3_key)
# Out:
# filepath:  audio4
# 'https://soulchain-dev1-output-video.s3.amazonaws.com/generated_videos/video_user1/audio4?AWSAccessKeyId=AKIAUJXLE2HEOGWEMCEX&Signature=F0VAtFK51%2Fq8aqaPKZ6u48unssA%3D&Expires=1716042250'

# %%
import tempfile

temp_dir = tempfile.gettempdir()
print("Temporary directory:", temp_dir)
# Out:
# Temporary directory: /var/folders/ys/s5c8y6vx2n95hnjtr5vs5h000000gn/T

# %%
import tempfile
from moviepy.editor import ImageClip, concatenate_videoclips, AudioFileClip
from PIL import Image
import numpy as np
import boto3
from io import BytesIO


try:
    # Fetch image from S3
    response_image = s3.get_object(Bucket='soulchain-dev1-output-video', Key="datalake_media/image-abdominal-pain-2493327_150.jpg-3aef656c-228a-42ed-bb7c-471369ad11ce")
    image_data = response_image['Body'].read()
except Exception as e:
    print("Error reading image from S3:", e)

image_stream = BytesIO(image_data)

# Convert image to numpy array
image = Image.open(image_stream)
image_np = np.array(image)

# Create image clip
image_clip = ImageClip(image_np, duration=10)

try:
    # Fetch audio from S3
    response_audio = s3.get_object(Bucket='soulchain-dev1-output-video', Key="generated_videos/video1/audio1")
    audio_data = response_audio['Body'].read()
except Exception as e:
    print("Error reading audio from S3:", e)

# Create a temporary file to write audio data
with tempfile.NamedTemporaryFile(suffix='.mp3') as temp_file:
    temp_file.write(audio_data)
    temp_file.seek(0)  # Reset file pointer to beginning
    
    audio_clip = AudioFileClip(temp_file.name)

image_clip = image_clip.set_duration(audio_clip.duration)

final_clip = concatenate_videoclips([image_clip.set_audio(audio_clip)])

with tempfile.NamedTemporaryFile(suffix='.mp4') as temp_output_file:
    temp_output_file_path = temp_output_file.name
    final_clip.write_videofile(temp_output_file_path, fps=24)

    try:
        s3.put_object(Body=temp_output_file.read(), Bucket='soulchain-dev1-output-video', Key='video_test')
        print("Successfully uploaded the final video to S3.")
    except Exception as e:
        print("Error uploading final video to S3:", e)
# Out:
# Moviepy - Building video /var/folders/ys/s5c8y6vx2n95hnjtr5vs5h000000gn/T/tmp6cvebxhc.mp4.
# MoviePy - Writing audio in tmp6cvebxhcTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /var/folders/ys/s5c8y6vx2n95hnjtr5vs5h000000gn/T/tmp6cvebxhc.mp4
# Moviepy - Done !
# Moviepy - video ready /var/folders/ys/s5c8y6vx2n95hnjtr5vs5h000000gn/T/tmp6cvebxhc.mp4
# Successfully uploaded the final video to S3.

# %%
import moviepy.editor as mp
import boto3
from moviepy.editor import VideoFileClip, concatenate_videoclips,CompositeAudioClip
import os
from moviepy.editor import ImageClip, concatenate_videoclips, AudioFileClip

# List of video clip paths
video_paths = [
    "generated_videos/video2/video2_part_1.mp4",
    "generated_videos/video2/video2_part_2.mp4",
    "generated_videos/video2/video2_part_3.mp4",
    "generated_videos/video2/video2_part_4.mp4",
    "generated_videos/video2/video2_part_5.mp4"
]

# Path to background music
background_music_path = "in_the_forest.mp3"
background_music = AudioFileClip(background_music_path)
background_music = background_music.volumex(0.2) 

clips = []
for key in video_paths:
    obj = s3.get_object(Bucket='soulchain-dev1-output-video', Key=key)
    file_path = key.split('/')[-1]
    with open(file_path, 'wb') as f:
        f.write(obj['Body'].read())
    clips.append(VideoFileClip(file_path))

# Concatenate video clips

final_video = concatenate_videoclips(clips, method="compose")
background_music = background_music.subclip(0, final_video.duration)
final_video = final_video.set_audio(CompositeAudioClip([final_video.audio, background_music]))

final_video.write_videofile(os.path.join('data', 'final_video_.mp4'), fps=24)

# Upload final video to S3
#with open(final_video_path, "rb") as f:
#    s3.upload_fileobj(f, 'soulchain-dev1-output-video', final_video_path)

# Delete temporary files
#for clip in clips:
#    clip.close()
#    os.remove(clip.filename)
#os.remove(final_video_path)
# Out:
# t:   0%|          | 2/641 [07:32<40:09:26, 226.24s/it, now=None]
# Moviepy - Building video data/final_video_.mp4.
# MoviePy - Writing audio in final_video_TEMP_MPY_wvf_snd.mp3
# t:   0%|          | 2/641 [07:32<40:11:22, 226.42s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video data/final_video_.mp4
# t:   0%|          | 2/641 [07:41<40:55:12, 230.54s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready data/final_video_.mp4

# %%
import json
from botocore.exceptions import ClientError

try:
    response = s3.get_object(Bucket='soulchain-dev1-output-video', Key='video_info.json')

    existing_data = json.loads(response['Body'].read())
except ClientError as e:
    if e.response['Error']['Code'] == 'NoSuchKey':
        existing_data = []
    else:
        raise

print("existing data:", existing_data)

existing_data = [entry for entry in existing_data if entry['user_id'] == 'user1']


image_paths = []
for entry in existing_data:
    image_paths.extend([part['image_key'] for part in entry['video_parts']])
# Out:
# existing data: [{'video_id': 'video3', 'user_id': 'user1', 'date_created': '2024-03-21T12:14:40.494881', 'video_key': 'generated_videos/video3/final_video.mp4', 'video_parts': [{'image_key': 'datalake_media/image-maldives-1993704_150.jpg-70ef5ccd-0d53-41b5-a054-016be29f2be5', 'audio_key': 'generated_videos/video3/audio1', 'text': "Nature's tranquility envelops us, with whispering trees and singing birds.", 'video_part_key': 'generated_videos/video3/video3_part_1.mp4'}, {'image_key': 'datalake_media/image-woman-3640935_150.jpg-57a84e56-ebe3-43ab-82e2-3962a8b15c0c', 'audio_key': 'generated_videos/video3/audio2', 'text': 'Rivers flow gently, sunlight paints warmth, and flowers bloom vibrantly.', 'video_part_key': 'generated_videos/video3/video3_part_2.mp4'}, {'image_key': 'datalake_media/image-winding-road-1556177_150.jpg-8be11ffb-2a1a-4b7c-914f-b3ff9cdc600b', 'audio_key': 'generated_videos/video3/audio3', 'text': 'Majestic mountains reach for the sky, while stars twinkle overhead.', 'v
# ...

# %%
image_path="datalake_media/image-maldives-1993704_150.jpg-70ef5ccd-0d53-41b5-a054-016be29f2be5"

if image_path in image_paths:
    print("yes")
# Out:
# yes

# %%
import pandas as pd
df=pd.DataFrame(existing_data)

# %%
df
# Out:
#   video_id user_id                date_created  \
# 0   video3   user1  2024-03-21T12:14:40.494881
# 1   video2   user1  2024-03-21T12:19:18.814486
#
#                                  video_key  \
# 0  generated_videos/video3/final_video.mp4
# 1  generated_videos/video2/final_video.mp4
#
#                                          video_parts
# 0  [{'image_key': 'datalake_media/image-maldives-...
# 1  [{'image_key': 'datalake_media/image-berries-3...

# %%
image_path = "datalake_media/image-maldives-1993704_150.jpg-70ef5ccd-0d53-41b5-a054-016be29f2be5"
image_paths = []

for entry in existing_data:
    image_paths.extend([part['image_key'] for part in entry['video_parts']])

if image_path in image_paths:
    for entry in existing_data:
        for part in entry['video_parts']:
            if part['image_key'] == image_path:
                date_created = entry['date_created']
                break
else:
    print("Image path not found in the provided data.")
# Out:
# Date created: 2024-03-21T12:14:40.494881

# %%
from datetime import datetime, timedelta

def image_used_in_30_days(image_path, date_now , existing_data):
    image_used=False 
    for entry in existing_data:
        for part in entry['video_parts']:
            if part['image_key'] == image_path:
                date_created = entry['date_created']
                break
    date_created = datetime.fromisoformat(date_created)
    if timedelta(days=-30)<=date_now - date_created <= timedelta(days=30):
        image_used=True 

    return image_used

date_now=datetime.now().isoformat()
date_now=datetime.fromisoformat(date_now)

image_used_in_30_days(image_path, date_now , existing_data)
# Out:
# True

# %%
date_created='2024-04-20T12:14:40.494881'
date_created=datetime.fromisoformat(date_created)
date_now=datetime.now().isoformat()
date_now=datetime.fromisoformat(date_now)

timedelta(days=-30)<=date_now - date_created <= timedelta(days=30)
# Out:
# True

# %%
date_now
# Out:
# datetime.datetime(2024, 3, 21, 15, 12, 24, 428732)

# %%
date_created
# Out:
# datetime.datetime(2024, 5, 21, 12, 14, 40, 494881)

# %%
from datetime import datetime, timedelta

# Convert date strings to datetime objects
date_created = '2024-05-21T12:14:40.494881'
date_created = datetime.fromisoformat(date_created)
date_now = datetime.now()

# Calculate the difference between date_now and date_created
difference = date_now - date_created

# Print the difference in days
print("Difference in days:", difference.days)
# Out:
# Difference in days: -61

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

data = [
    {"name": "Image1", "topic": "nature", "keywords": "ai_generated, flower, cherry blossom", "keywords_from_description": "tree, picture, branch, single, close"},
    {"name": "Image2", "topic": "egg", "keywords": "egg, smiling, happy", "keywords_from_description": "bear, cartoon, cake, sitting"},
    {"name": "Image3", "topic": "Food", "keywords": "pizza, pasta, italian", "keywords_from_description": "cheese, tomato, delicious"}
]

def calculate_similarity(keywords1, keywords2):
    tokens1 = word_tokenize(keywords1)
    tokens2 = word_tokenize(keywords2)
    
    stop_words = set(stopwords.words('english'))
    filtered_tokens1 = [word for word in tokens1 if word.lower() not in stop_words]
    filtered_tokens2 = [word for word in tokens2 if word.lower() not in stop_words]
    
    intersection = len(set(filtered_tokens1).intersection(filtered_tokens2))
    union = len(set(filtered_tokens1).union(filtered_tokens2))
    similarity = intersection / union if union != 0 else 0
    return similarity

for item in data:
    keyword_similarity = calculate_similarity(item["keywords"], item["topic"])
    description_similarity = calculate_similarity(item["keywords_from_description"], item["topic"])
    
    if keyword_similarity > description_similarity:
        print(f"For {item['name']}, the keywords '{item['keywords']}' align better with the topic '{item['topic']}'")
    elif description_similarity > keyword_similarity:
        print(f"For {item['name']}, the keywords from description '{item['keywords_from_description']}' align better with the topic '{item['topic']}'")
    elif description_similarity == keyword_similarity:
        print(f"For {item['name']}, both sets of keywords equally align with the topic '{item['topic']}'")
    else :
        print(f"For {item['name']}, both sets of keywords no one align with the topic '{item['topic']}'")
# Out:
# For Image1, both sets of keywords equally align with the topic 'nature'
# For Image2, the keywords 'egg, smiling, happy' align better with the topic 'egg'
# For Image3, both sets of keywords equally align with the topic 'Food'

# %%
import re

image_data = {
    "name": "Image1",
    "topic": "ai generated",
    "keywords": "ai generated, flower, cherry blossom",
    "keywords_from_description": "tree, picture, branch, single, close"
}

keywords_from_description = re.findall(r'\b\w+\b', image_data["keywords_from_description"])

all_keywords = image_data["keywords"].split(", ") + keywords_from_description

main_topic = max(set(all_keywords), key=all_keywords.count)

print("Main topic of the image:", main_topic)
# Out:
# Main topic of the image: ai generated

# %%
import pandas as pd

# Sample data
data = {
    'name': [ 'image3'],
    'topic': [ ['ai generated']],
    'keywords': [ ['food', 'fruit']],
    'keywords_from_description': [  ['healthy', 'snack', 'juicy']]
}

# Create DataFrame
df = pd.DataFrame(data)

# Combine keywords and keywords_from_description into one column
df['combined_keywords'] = df['keywords'] + df['keywords_from_description'] +df['topic']

# Flatten the combined keywords list
all_keywords = [keyword for sublist in df['combined_keywords'] for keyword in sublist]

# Calculate the frequency of each term
keyword_freq = pd.Series(all_keywords).value_counts()

# Select the term with the highest frequency
best_term = keyword_freq.idxmax()

print("Best term to describe the image:", best_term)
# Out:
# Best term to describe the image: food

# %%
import pandas as pd

data = {
    'name': ['image3'],
    'topic': [['lunch']],
    'keywords': [['lunch', 'meal', 'people']],
    'keywords_from_description': [['laptop', 'kitchen', 'computer', 'person', 'using']]
}

df = pd.DataFrame(data)

df['combined_keywords'] = df['keywords'] + df['keywords_from_description'] + df['topic']

all_keywords = [keyword for sublist in df['combined_keywords'] for keyword in sublist]

keyword_freq = pd.Series(all_keywords).value_counts()

best_term = keyword_freq.idxmax()

df['main_topic'] = best_term

print("Best term to describe the image:", best_term)
df
# Out:
# Best term to describe the image: lunch
#      name    topic               keywords  \
# 0  image3  [lunch]  [lunch, meal, people]
#
#                     keywords_from_description  \
# 0  [laptop, kitchen, computer, person, using]
#
#                                    combined_keywords main_topic
# 0  [lunch, meal, people, laptop, kitchen, compute...      lunch

# %%
keyword_freq
# Out:
# lunch       2
# meal        1
# people      1
# laptop      1
# kitchen     1
# computer    1
# person      1
# using       1
# Name: count, dtype: int64

# %%
import pandas as pd

def find_best_term(row):
    combined_keywords = row['keywords'] + row['keywords_from_description'] + row['topic']
    
    keyword_freq = pd.Series(combined_keywords).value_counts()

    best_term = keyword_freq.idxmax()

    return best_term

data = {
    'name': ['image1', 'image2', 'image3'],
    'topic': [['crocus'], ['landscape'], ['nutrition']],
    'keywords': [['crocus', 'flower', 'field'], ['nature', 'landscape'], ['food', 'fruit']],
    'keywords_from_description': [['flowers', 'flower', 'pot', 'group', 'large'], ['mountain', 'scenic', 'view'], ['healthy', 'snack', 'juicy']]
}

df = pd.DataFrame(data)

df['main_topic'] = df.apply(find_best_term, axis=1)

# %%
df
# Out:
#      name        topic                 keywords  \
# 0  image1     [crocus]  [crocus, flower, field]
# 1  image2  [landscape]      [nature, landscape]
# 2  image3  [nutrition]            [food, fruit]
#
#               keywords_from_description main_topic
# 0  [flowers, flower, pot, group, large]     crocus
# 1              [mountain, scenic, view]  landscape
# 2               [healthy, snack, juicy]       food

# %%
import pandas as pd
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

porter = PorterStemmer()

def stem_words(words):
    tokens = word_tokenize(words)
    stemmed_words = [porter.stem(word) for word in tokens]
    return stemmed_words

def find_best_term(row):
    combined_keywords = row['keywords'] + row['keywords_from_description'] + row['topic']
    
    stemmed_keywords = stem_words(' '.join(combined_keywords))
    
    keyword_freq = pd.Series(stemmed_keywords).value_counts()

    best_term = keyword_freq.idxmax()

    return best_term

df['main_topic'] = df.apply(find_best_term, axis=1)
df
# Out:
#      name        topic                 keywords  \
# 0  image1     [crocus]  [crocus, flower, field]
# 1  image2  [landscape]      [nature, landscape]
# 2  image3  [nutrition]            [food, fruit]
#
#               keywords_from_description main_topic
# 0  [flowers, flower, pot, group, large]     flower
# 1              [mountain, scenic, view]   landscap
# 2               [healthy, snack, juicy]       food

# %%
df=pd.read_excel("metadata.xlsx")

# %%
df['topic_name'] = df['name'].str.split('-').str[0].apply(lambda x: [x])

# %%
df['keywords_description'] = df['keywords_description'].apply(lambda x: eval(x))
df['keywords'] = df['keywords'].apply(lambda x: eval(x))

# %%
import pandas as pd
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

porter = PorterStemmer()

def stem_words(words):
    tokens = word_tokenize(words)
    stemmed_words = [porter.stem(word) for word in tokens]
    return stemmed_words

def find_main_terms(row, n=3):
    combined_keywords = row['topic_name']+ row['keywords'] + row['keywords_description'] 
    
    stemmed_keywords = stem_words(' '.join(combined_keywords))
    
    keyword_freq = pd.Series(stemmed_keywords).value_counts()

    top_terms = keyword_freq.head(n).index.tolist()

    return top_terms

df['main_topic'] = df.apply(find_main_terms, axis=1)

# %%
df
# Out:
#                               name                                keywords  \
# 0     fresh-fruits-2305192_150.jpg      [fresh fruits, bowls, fruit bowls]
# 1       vegetables-1085063_150.jpg              [vegetables, fruits, food]
# 2         olive-oil-968657_150.jpg               [olive oil, olives, food]
# 3          berries-3504149_150.jpg             [berries, fruit, nutrition]
# 4       vegetables-3679075_150.jpg      [vegetables, ingredients, harvest]
# ...                            ...                                     ...
# 4351         apples-575317_150.png                   [apples, fruit, food]
# 4352     persimmon-1914127_150.jpg             [persimmon, fruits, orange]
# 4353     sunflower-1127174_150.jpg              [sunflower, flower, plant]
# 4354     sunflower-3113318_150.jpg  [sunflower, nature, flower background]
# 4355     sunflower-1627193_150.jpg             [sunflower, yellow, flower]
#
# ...

# %%
def stem_words(word):
    porter = PorterStemmer()
    stemmed_word = porter.stem(word) 
    return stemmed_word


stem_words("nutrition")
# Out:
# 'nutrit'

# %%
import pandas as pd

# %%
df_image=pd.read_excel('metadata copy.xlsx')
df_image=df_image.head(1)

# %%
print(df_image)
# Out:
#                            name                                  keywords  \
# 0  fresh-fruits-2305192_150.jpg  ['fresh fruits', 'bowls', 'fruit bowls']
#
#                                                  url   type       term  \
# 0  https://cdn.pixabay.com/photo/2017/05/11/19/44...  image  Nutrition
#
#                                        path_datalake  \
# 0  datalake_media/image-fresh-fruits-2305192_150....
#
#                                          description  \
# 0  a bowl filled with fruit and vegetables on top...
#
#                                 keywords_description   source
# 0  ['vegetables', 'fruit', 'bowl', 'table', 'wood...  pixabay

# %%
from scrapping_api_image import find_main_terms
df_image['term'] = df_image['term'].astype(str)
df_image['topic_name'] = df_image['name'].str.split('-').str[0].apply(lambda x: [x])
df_image['keywords_description'] = df_image['keywords_description'].apply(lambda x: eval(x))
df_image['keywords'] = df_image['keywords'].apply(lambda x: eval(x))
df_image['main_topic'] = df_image.apply(find_main_terms, axis=1)

# %%
df_image
# Out:
#                            name                            keywords  \
# 0  fresh-fruits-2305192_150.jpg  [fresh fruits, bowls, fruit bowls]
#
#                                                  url   type       term  \
# 0  https://cdn.pixabay.com/photo/2017/05/11/19/44...  image  Nutrition
#
#                                        path_datalake  \
# 0  datalake_media/image-fresh-fruits-2305192_150....
#
#                                          description  \
# 0  a bowl filled with fruit and vegetables on top...
#
#                        keywords_description   source topic_name main_topic
# 0  [vegetables, fruit, bowl, table, wooden]  pixabay    [fresh]    [fruit]

# %%
import ast

string_representation = "['fresh fruits', 'bowls', 'fruit bowls']"
list_representation = ast.literal_eval(string_representation)
print(list_representation)
# Out:
# ['fresh fruits', 'bowls', 'fruit bowls']

# %%
from nltk.corpus import wordnet

def lexical_similarity(word1, word2):
    synsets1 = wordnet.synsets(word1)
    synsets2 = wordnet.synsets(word2)

    max_similarity = 0

    for synset1 in synsets1:
        for synset2 in synsets2:
            similarity = synset1.wup_similarity(synset2)  # Wu-Palmer Similarity
            if similarity is not None and similarity > max_similarity:
                max_similarity = similarity

    return max_similarity

# %%
lexical_similarity('woman','phone')
# Out:
# 0.4444444444444444

# %%
lexical_similarity('','')
# Out:
# 0.3076923076923077

# %%
lexical_similarity('spanish','apple')
# Out:
# 0.16666666666666666

# %%
lexical_similarity('vegetable','potato')
# Out:
# 0.875

# %%
lexical_similarity('flower','tree')
# Out:
# 0.7619047619047619

# %%
lexical_similarity('vitamin','zinc')
# Out:
# 0.42857142857142855

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from gensim import corpora, models
import spacy
from spacy.util import fix_random_seed
from keybert import KeyBERT
import elevenlabs
from elevenlabs import Voice, VoiceSettings, generate, save
from datalake import put_image_in_s3

def split_sentence(sentence, max_length=100):
    nlp = spacy.load('en_core_web_sm')
    
    if len(sentence) > max_length:
        # First, try splitting by ','
        if ', ' in sentence:
            parts = sentence.split(',')
            num_parts = len(parts)
            split_index = num_parts // 2

            # Find the optimal split index by minimizing the absolute difference in lengths
            optimal_split_index = split_index
            min_length_diff = abs(sum(len(part) for part in parts[:split_index]) - sum(len(part) for part in parts[split_index:]))
            for i in range(split_index + 1, num_parts):
                length_diff = abs(sum(len(part) for part in parts[:i]) - sum(len(part) for part in parts[i:]))
                if length_diff < min_length_diff:
                    optimal_split_index = i
                    min_length_diff = length_diff

            part1 = ','.join(parts[:optimal_split_index])
            part2 = ','.join(parts[optimal_split_index:])
                        
            return part1, part2
        
        # If ',' not found, proceed with original logic
        length = len(sentence) // 2
        split_index = sentence.rfind(" ", 0, int(length))

        if split_index != -1:
            part1 = sentence[:split_index].strip()
            part2 = sentence[split_index + 1:].strip()

            last_word_part1 = nlp(part1.split()[-1])
            if last_word_part1 and last_word_part1[0].pos_ == 'VERB':
                part1 = ' '.join(part1.split()[:-1]).strip()
                part2 = last_word_part1.text + ' ' + part2

                return part1, part2

        doc = nlp(sentence)
        for token in reversed(doc):
            if token.pos_ == 'VERB':
                split_index = token.idx
                part1 = sentence[:split_index].strip()
                part2 = sentence[split_index:].strip()
                return part1, part2

        part1 = sentence[:max_length].strip()
        part2 = sentence[max_length:].strip()
        return part1, part2
    else:
        return sentence, None


def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    sentences = sent_tokenize(text)
    tokenized_sentences = [nltk.word_tokenize(sentence.lower()) for sentence in sentences]
    filtered_sentences = [
        [word for word in sentence if word.isalnum() and word not in stop_words]
        for sentence in tokenized_sentences
    ]
    return sentences, filtered_sentences

def clean_terms(top_terms):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(' '.join(top_terms))
    cleaned_terms = [
        token.text
        for token in doc
        if token.pos_ in ['NOUN']
    ]
    return cleaned_terms

def extract_keywords(text):
    keybert = KeyBERT()
    keywords = keybert.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words='english')
    return [keyword[0] for keyword in keywords]

def find_topics(text):
    np.random.seed(42)

    sentences, filtered_sentences = preprocess_text(text)

    dictionary = corpora.Dictionary(filtered_sentences)
    corpus = [dictionary.doc2bow(sentence) for sentence in filtered_sentences]

    np.random.seed(42)

    lda_model = models.LdaModel(corpus, num_topics=len(sentences), id2word=dictionary, passes=15, random_state=42)

    topic_data = []
    for sentence_id, sentence in enumerate(sentences):
        part1, part2 = split_sentence(sentence)
        original_sentence = sentence  # Store the original sentence before any splitting

        if part2:
            topics_part1 = lda_model.get_document_topics(corpus[sentence_id])
            topics_part2 = lda_model.get_document_topics(dictionary.doc2bow(part2.lower().split()))
            combined_topics = topics_part1 + topics_part2

            top_topic = max(combined_topics, key=lambda x: x[1])
            top_terms = [term[0] for term in lda_model.show_topic(top_topic[0])]
            cleaned_terms = clean_terms(top_terms)

            topic_data.append({'id': sentence_id + 1, 'original_sentence': original_sentence, 'sentence': part1, 'topic': top_topic[0] + 1, 'terms': cleaned_terms})
            topic_data.append({'id': sentence_id + 1, 'original_sentence': original_sentence, 'sentence': part2, 'topic': top_topic[0] + 1, 'terms': cleaned_terms})
        else:
            topics = lda_model.get_document_topics(corpus[sentence_id])
            top_topic = max(topics, key=lambda x: x[1])
            top_terms = [term[0] for term in lda_model.show_topic(top_topic[0])]
            cleaned_terms = clean_terms(top_terms)

            if 'topic' not in locals():
                keywords = extract_keywords(original_sentence)
                cleaned_terms = keywords

            topic_data.append({'id': sentence_id + 1, 'original_sentence': original_sentence, 'sentence': sentence, 'topic': top_topic[0] + 1, 'terms': cleaned_terms})

    df = pd.DataFrame(topic_data)
    df['sentence_part_id'] = df.index

    return df

# %%
df=find_topics("Did you know? Glucose fluctuations can directly impact brain function in those with Type 1 Diabetes. A groundbreaking study utilized digital sensors and smartphone tests to reveal this connection. Results? Cognitive speed dips with high or low glucose, but not attention span. Interestingly, everyone's brain responds differently, especially older adults and those with health conditions. Peak cognitive performance occurs at glucose levels slightly above the norm highlighting a balance unique to each individual. Minimizing glucose fluctuations could be key to maintaining cognitive sharpness.")

# %%
df
# Out:
#    id                                  original_sentence  \
# 0   1                                      Did you know?
# 1   2  Glucose fluctuations can directly impact brain...
# 2   3  A groundbreaking study utilized digital sensor...
# 3   4                                           Results?
# 4   5  Cognitive speed dips with high or low glucose,...
# 5   6  Interestingly, everyone's brain responds diffe...
# 6   6  Interestingly, everyone's brain responds diffe...
# 7   7  Peak cognitive performance occurs at glucose l...
# 8   7  Peak cognitive performance occurs at glucose l...
# 9   8  Minimizing glucose fluctuations could be key t...
#
#                                             sentence  topic  \
# 0                                      Did you know?      4
# 1  Glucose fluctuations can directly impact brain...      8
# 2  A groundbreaking study utilized digital sensor...      7
# 3                                           Results?      4
# ...

# %%
from moviepy.editor import VideoFileClip, TextClip, AudioFileClip, concatenate_videoclips, CompositeAudioClip, CompositeVideoClip
import tempfile
from moviepy.editor import VideoFileClip
try:
    response_video = s3.get_object(Bucket='soulchain-dev1-output-video', Key='datalake_media/video-social-media-1360.mp4-e07966bb-9bc0-40af-b4cd-370eade0e8b0')
    video_data = response_video['Body'].read()
except Exception as e:
    print("Error reading video from S3:", e)
    video_data = None

# Write video data to a temporary file
with tempfile.NamedTemporaryFile() as temp_file:
    temp_file.write(video_data)
    temp_file.flush()

    # Load the video file into a VideoFileClip object
    final_video_width, final_video_height = 1920, 1080  
    video_clip = VideoFileClip(temp_file.name).set_duration(10)  # Change to load video clip
    video_clip = video_clip.resize((final_video_width, final_video_height))

# %%
output_file_path = 'output_video.mp4'
video_clip.write_videofile(output_file_path, codec='libx264', fps=30)
# Out:
# Moviepy - Building video output_video.mp4.
# Moviepy - Writing video output_video.mp4
# Moviepy - Done !
# Moviepy - video ready output_video.mp4

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from gensim import corpora, models
import spacy
from spacy.util import fix_random_seed
from keybert import KeyBERT
import elevenlabs
from elevenlabs import Voice, VoiceSettings, generate, save
from datalake import put_image_in_s3
import requests
import time  
from langdetect import detect
import pandas as pd
from argostranslate import translate
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag


def get_argos_model(source, target):
    lang = f'{source} -> {target}'
    source_lang = [model for model in translate.get_installed_languages() if lang in map(repr, model.translations_from)]
    target_lang = [model for model in translate.get_installed_languages() if lang in map(repr, model.translations_to)]
    
    return source_lang[0].get_translation(target_lang[0])



def split_sentence(lang,sentence, max_length=100):
    if lang=='en':
        nlp = spacy.load(f"{lang}_core_web_sm")
    else:
        nlp = spacy.load(f"{lang}_core_news_sm")
    
    if len(sentence) > max_length:
        # First, try splitting by ','
        if ', ' in sentence:
            parts = sentence.split(',')
            num_parts = len(parts)
            split_index = num_parts // 2

            # Find the optimal split index by minimizing the absolute difference in lengths
            optimal_split_index = split_index
            min_length_diff = abs(sum(len(part) for part in parts[:split_index]) - sum(len(part) for part in parts[split_index:]))
            for i in range(split_index + 1, num_parts):
                length_diff = abs(sum(len(part) for part in parts[:i]) - sum(len(part) for part in parts[i:]))
                if length_diff < min_length_diff:
                    optimal_split_index = i
                    min_length_diff = length_diff

            part1 = ','.join(parts[:optimal_split_index])
            part2 = ','.join(parts[optimal_split_index:])
                        
            return part1, part2
        
        # If ',' not found, proceed with original logic
        length = len(sentence) // 2
        split_index = sentence.rfind(" ", 0, int(length))

        if split_index != -1:
            part1 = sentence[:split_index].strip()
            part2 = sentence[split_index + 1:].strip()

            last_word_part1 = nlp(part1.split()[-1])
            if last_word_part1 and last_word_part1[0].pos_ == 'VERB':
                part1 = ' '.join(part1.split()[:-1]).strip()
                part2 = last_word_part1.text + ' ' + part2

                return part1, part2

        doc = nlp(sentence)
        for token in reversed(doc):
            if token.pos_ == 'VERB':
                split_index = token.idx
                part1 = sentence[:split_index].strip()
                part2 = sentence[split_index:].strip()
                return part1, part2

        part1 = sentence[:max_length].strip()
        part2 = sentence[max_length:].strip()
        return part1, part2
    else:
        return sentence, None

def get_argos(lang):
    if lang=='fr':
        lang='French'
    if lang=='de':
        lang='German'
    if lang=='es':
        lang='Spanish'
    if lang=='pt':
        lang='Portuguese'
    if lang=='ko':
        lang='Korean'
    if lang=='ja':
        lang='Japanese'
    if lang=='ru':
        lang='Russian'
    if lang=='ar':
        lang='Arabic'
    if lang=='it':
        lang='Italian'
    argos_model=get_argos_model(lang, "English")
    return argos_model

def preprocess_text(lang,text):

    stop_words = set(stopwords.words('english'))
    sentences = sent_tokenize(text)
    if lang!='en':
        argos_model=get_argos(lang)
        new_text=argos_model.translate(text)
    else :
        new_text=text
    en_sentences=sent_tokenize(new_text)
    tokenized_sentences = [nltk.word_tokenize(en_sentences.lower()) for en_sentences in en_sentences]
    filtered_sentences = [
        [word for word in en_sentences if word.isalnum() and word not in stop_words]
        for en_sentences in tokenized_sentences
    ]
    return sentences, filtered_sentences

def clean_terms(top_terms):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(' '.join(top_terms))
    cleaned_terms = [
        token.text
        for token in doc
        if token.pos_ in ['NOUN']
    ]
    return cleaned_terms

def extract_keywords(text):
    keybert = KeyBERT()
    keywords = keybert.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words='english')
    return [keyword[0] for keyword in keywords]

def find_topics(text):

    lang=detect(text)

    np.random.seed(42)

    sentences, filtered_sentences = preprocess_text(lang,text)
    print(filtered_sentences)

    dictionary = corpora.Dictionary(filtered_sentences)
    corpus = [dictionary.doc2bow(sentence) for sentence in filtered_sentences]

    np.random.seed(42)

    lda_model = models.LdaModel(corpus, num_topics=len(sentences), id2word=dictionary, passes=15, random_state=42)

    topic_data = []

    for sentence_id, sentence in enumerate(sentences):
        part1, part2 = split_sentence(lang,sentence)

        if lang!="en":
            argos_model=get_argos(lang)
            original_sentence=argos_model.translate(sentence)
        else: 
            original_sentence = sentence 

        if part2:
            bow = dictionary.doc2bow(original_sentence.lower().split())
            topics = lda_model.get_document_topics(bow)            
            top_topic = max(topics, key=lambda x: x[1])
            top_terms = [term[0] for term in lda_model.show_topic(top_topic[0])]
            cleaned_terms = clean_terms(top_terms)

            topic_data.append({'id': sentence_id + 1, 'original_sentence': original_sentence, 'sentence': part1, 'topic': top_topic[0] + 1, 'terms': cleaned_terms})
            topic_data.append({'id': sentence_id + 1, 'original_sentence': original_sentence, 'sentence': part2, 'topic': top_topic[0] + 1, 'terms': cleaned_terms})
    
        else:
            print(original_sentence)
            bow = dictionary.doc2bow(original_sentence.lower().split())
            topics = lda_model.get_document_topics(bow)
            top_topic = max(topics, key=lambda x: x[1])
            top_terms = [term[0] for term in lda_model.show_topic(top_topic[0])]
            cleaned_terms = clean_terms(top_terms)

            if 'topic' not in locals():
                keywords = extract_keywords(original_sentence)
                cleaned_terms = keywords

            topic_data.append({'id': sentence_id + 1, 'original_sentence': original_sentence, 'sentence': sentence, 'topic': top_topic[0] + 1, 'terms': cleaned_terms})

    df = pd.DataFrame(topic_data)
    df['sentence_part_id'] = df.index

    return df

# %%
find_topics("From anxiety to cancer, the evidence against ultra-processed food piles up. Americans now consume over half of their daily calories from these foods. Studies reveal a heightened risk of anxiety, depression obesity, metabolic syndrome, and certain cancers.")
# Out:
# [['anxiety', 'cancer', 'evidence', 'food', 'piles'], ['americans', 'consume', 'half', 'daily', 'calories', 'foods'], ['studies', 'reveal', 'heightened', 'risk', 'anxiety', 'depression', 'obesity', 'metabolic', 'syndrome', 'certain', 'cancers']]
# From anxiety to cancer, the evidence against ultra-processed food piles up.
# Americans now consume over half of their daily calories from these foods.
#    id                                  original_sentence  \
# 0   1  From anxiety to cancer, the evidence against u...
# 1   2  Americans now consume over half of their daily...
# 2   3  Studies reveal a heightened risk of anxiety, d...
# 3   3  Studies reveal a heightened risk of anxiety, d...
#
#                                             sentence  topic  \
# 0  From anxiety to cancer, the evidence against u...      1
# 1  Americans now consume over half of their daily...      2
# 2  Studies reveal a heightened risk of anxiety, d...      2
# ...

# %%
find_topics("De l'anxiété au cancer, les preuves contre les aliments ultra-transformés s'accumulent. Les Américains consomment maintenant plus de la moitié de leurs calories quotidiennes de ces aliments. Les études révèlent un risque accru d'anxiété, de dépression, d'obésité, de syndrome métabolique et de certains cancers.")
# Out:
# [['anxiety', 'cancer', 'evidence', 'foods', 'accumulates'], ['americans', 'consume', 'half', 'daily', 'calories', 'foods'], ['studies', 'show', 'increased', 'risk', 'anxiety', 'depression', 'obesity', 'metabolic', 'syndrome', 'cancers']]
# From anxiety to cancer, evidence against ultra-transformed foods accumulates.
#    id                                  original_sentence  \
# 0   1  From anxiety to cancer, evidence against ultra...
# 1   2  Americans now consume more than half of their ...
# 2   2  Americans now consume more than half of their ...
# 3   3  Studies show an increased risk of anxiety, dep...
# 4   3  Studies show an increased risk of anxiety, dep...
#
#                                             sentence  topic  \
# 0  De l'anxiété au cancer, les preuves contre les...      3
# 1                                     Les Américains      1
# 2  consomment maintenant plus de la moitié de leu...      1
# 3  Les études révèlent un risque accru d'anxiété,...      2
# ...

# %%
lang='en'
text=f"{lang}_core_web_sm"

# %%
import spacy
spacy.cli.download("de_core_news_sm")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 9.5 MB/s eta 0:00:0000:01m00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from topic import find_topics

# %%
find_topics("From anxiety to cancer, the evidence against ultra-processed food piles up. Americans now consume over half of their daily calories from these foods. Studies reveal a heightened risk of anxiety, depression obesity, metabolic syndrome, and certain cancers.")
# Out:
#    id                                  original_sentence  \
# 0   1  From anxiety to cancer, the evidence against u...
# 1   2  Americans now consume over half of their daily...
# 2   3  Studies reveal a heightened risk of anxiety, d...
# 3   3  Studies reveal a heightened risk of anxiety, d...
#
#                                             sentence  topic  \
# 0  From anxiety to cancer, the evidence against u...      1
# 1  Americans now consume over half of their daily...      2
# 2  Studies reveal a heightened risk of anxiety, d...      2
# 3           metabolic syndrome, and certain cancers.      2
#
#                                            terms  sentence_part_id
# 0      [cancer, anxiety, food, piles, processed]                 0
# 1    [calories, foods, consume, americans, half]                 1
# 2  [studies, depression, obesity, risk, cancers]                 2
# 3  [studies, depression, obesity, risk, cancers]                 3

# %%
import pandas as pd

def update_media(df, media_path):
    df.loc[df['path_datalake'] == media_path, 'count_edit'] += 1

    condition = (df['count_edit'] >= 10) & (df['count_edit'] / df['count_usage'] < 0.5)

    df.loc[(df['path_datalake'] == media_path) & condition, 'media_state'] = 'not useful'
    
    return df

df=pd.read_excel("metadata.xlsx")
df=update_media(df,"datalake")

# %%
df
# Out:
#       Unnamed: 0                          name  \
# 0              3         iphone-160307_150.png
# 1              4  mobile-phone-1875813_150.jpg
# 2              5         office-620822_150.jpg
# 3              6   train-track-2507499_150.jpg
# 4              7    smartphone-1894723_150.jpg
# ...          ...                           ...
# 5004        5194         apples-575317_150.png
# 5005        5195     persimmon-1914127_150.jpg
# 5006        5196     sunflower-1127174_150.jpg
# 5007        5197     sunflower-3113318_150.jpg
# 5008        5198     sunflower-1627193_150.jpg
#
#                                                keywords  \
# 0                     ['iphone', 'cell phone', 'phone']
# 1     ['mobile phone', 'smartphone', 'hohenzollern c...
# 2                  ['office', 'business', 'accountant']
# 3             ['train track', 'railroad', 'smartphone']
# 4            ['smartphone', 'cellphone', 'touchscreen']
# ...

# %%
from moviepy.editor import VideoFileClip, ImageClip, TextClip, AudioFileClip, concatenate_videoclips, CompositeAudioClip, CompositeVideoClip

list=TextClip.list('font')

# %%
df=pd.DataFrame(list)

# %%
df.to_csv("font_style.csv")

# %%
import pandas as pd
df= pd.read_csv("test3.csv")

# %%
df=df.rename(columns={"Unnamed: 0":"sentence_part_id"})
df
# Out:
#    sentence_part_id                                           sentence
# 0                 0  Nature's tranquility envelops us, with whisper...
# 1                 1  Rivers flow gently, sunlight paints warmth, an...
# 2                 2  Majestic mountains reach for the sky, while st...
# 3                 3  In nature's embrace, peace reigns, offering a ...

# %%
import boto3
from botocore.exceptions import ClientError
import elevenlabs
from elevenlabs import Voice, VoiceSettings, generate, save
import elevenlabs



session = boto3.Session(region_name='eu-west-1')
s3 = session.client('s3',aws_access_key_id="AKIAUJXLE2HEOGWEMCEX",aws_secret_access_key="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")
eleven_api="e3a9b4546de3b481827f7480c0af5c74"

import tempfile

def audio_generation(s3, df, video_id, eleven_api):
    elevenlabs.set_api_key(eleven_api)
    for sentence_id, sentence in zip(df['sentence_part_id'], df['sentence']):
        audio = generate(
            text=sentence,
            voice=Voice(
                voice_id='EXAVITQu4vr4xnSDxMaL',
                settings=VoiceSettings(stability=0.71, similarity_boost=0.5, style=0.0, use_speaker_boost=True)
            )
        )
        with tempfile.NamedTemporaryFile(suffix='.mp3', delete=False) as temp_file:
            temp_file.write(audio)
            temp_file.seek(0)
            s3.upload_file(temp_file.name, 'soulchain-dev1-output-video', f"generated_videos/{video_id}/audio{sentence_id+1}.mp3")

audio_generation(s3, df, "video80", eleven_api)

# %%
def update_text_in_json(s3,video_id, text_keys, new_texts):
    try:
        response = s3.get_object(Bucket='soulchain-dev1-output-video', Key='video_info.json')
        data = json.loads(response['Body'].read())
    except ClientError as e:
        if e.response['Error']['Code'] == 'NoSuchKey':
            data = []
        else:
            raise  

    video = next((v for v in data if v["video_id"] == video_id), None)

    if video:
        for text_key, new_text in zip(text_keys, new_texts):
            part = next((p for p in video["video_parts"] if p["key"] == text_key), None)
            if part:
                part["text"] = new_text
    try:
        data = json.dumps(data)
        s3.put_object(Bucket='soulchain-dev1-output-video', Key=f"video_info.json", Body=data)
        print("JSON file successfully updated.")
    except Exception as e:
        print(f"Error while saving the JSON file: {e}")

# %%
import json
session = boto3.Session(region_name='eu-west-1')
s3 = session.client('s3',aws_access_key_id="AKIAUJXLE2HEOGWEMCEX",aws_secret_access_key="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")
eleven_api="e3a9b4546de3b481827f7480c0af5c74"

update_text_in_json(s3, 'video3',[1,3],["hi", 'hello'])
# Out:
# JSON file successfully updated.

# %%
# Concatenate the lists
text_keys=[1,4]
audio_keys=[2,6]
media_keys=[1,3]
final_keys = text_keys + audio_keys + media_keys
final_keys = list(set(final_keys))

# %%
final_keys
# Out:
# [1, 2, 3, 4, 6]

# %%
try:
    response = s3.get_object(Bucket='soulchain-dev1-output-video', Key='video_info.json')

    data = json.loads(response['Body'].read())
except ClientError as e:
    if e.response['Error']['Code'] == 'NoSuchKey':
        data = []
    else:
        raise
video = next((v for v in data if v["video_id"] == "video3"), None)

keys = []
if video and "video_parts" in video:
    keys = [part['key'] for part in video['video_parts']]

# %%
import boto3
from PIL import Image
import io
local_image_path = 'default_image.jpg' 
with open(local_image_path, 'rb') as f:
    image_data = f.read()  

image = Image.open(io.BytesIO(image_data))

# %%
from datalake import put_image_in_s3
import requests
import uuid

def download_media(media, media_type):

    if media_type == 'image':
        preview_url = media['previewURL']
        url = media.get('largeImageURL', media.get('previewURL'))
        filename = preview_url.split('/')[-1]

    else:
        url = media.get('videos', {}).get('large', {}).get('url')
        filename = url.split('/')[-1].split('?')[0]
    if not url:
        print("URL is invalid or missing")
        return None, None
    
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to download media. HTTP Status Code: {response.status_code}")
        return None, None
     
    s3_key = f"datalake_media/{media_type}-{filename}-{str(uuid.uuid4())}"
    put_image_in_s3(response.content, 'soulchain-dev1-output-video', s3_key)

    return s3_key

# %%
media = {
"id": 8618301,
"pageURL": "https://pixabay.com/photos/simba-cat-portrait-cat-photography-8618301/",
"type": "photo",
"tags": "simba, cat, portrait",
"previewURL": "https://cdn.pixabay.com/photo/2024/03/07/10/38/simba-8618301_150.jpg",
"previewWidth": 150,
"previewHeight": 100,
"webformatURL": "https://pixabay.com/get/g0adee4efae083d05c53188f183690504db2e7a949c0e67c5bdec4c08fef877a9ed5dd04b843acf8b8c9181f702c23ca2a9d6857a146e51426aa1761b879d7f4f_640.jpg",
"webformatWidth": 640,
"webformatHeight": 426,
"largeImageURL": "https://pixabay.com/get/gd621162f9453f20b08abad70079dd52870ddeaba78c8caf2a4fdd3e11511cd3ceec0e634f823df4700bea8789035c1887592da9bec02936171493900b3648986_1280.jpg",
"imageWidth": 6016,
"imageHeight": 4000,
"imageSize": 6194350,
"views": 18726,
"downloads": 15280,
"collections": 63,
"likes": 112,
"comments": 16,
"user_id": 5211440,
"user": "Jill-Schafer-Creative-Lab",
"userImageURL": "https://cdn.pixabay.com/user/2022/09/07/09-11-48-369_250x250.png"
}

download_media(media,'image')
# Out:
# Media uploaded successfully to S3
# 'datalake_media/image-simba-8618301_150.jpg-4bcb995a-78bb-4af0-95c1-adc7d60364fe'

# %%
def replace_audio(s3,video_id,key, audio):    
    s3.upload_file(audio, 'soulchain-dev1-output-video', f"generated_videos/{video_id}/audio{key}")

# %%
from moviepy.editor import TextClip,concatenate_videoclips
import requests
from langdetect import detect


def get_argos(lang):


    if lang=='en':
        lang='English'
    if lang=='fr':
        lang='French'
    if lang=='de':
        lang='German'
    if lang=='es':
        lang='Spanish'
    if lang=='pt':
        lang='Portuguese'
    if lang=='ko':
        lang='Korean'
    if lang=='ja':
        lang='Japanese'
    if lang=='ru':
        lang='Russian'
    if lang=='ar':
        lang='Arabic'
    if lang=='it':
        lang='Italian'

    return lang


lang="French"

sentence="Wondering how protein impacts blood sugar levels?"
original_lang=detect(sentence)
original_lang = get_argos(original_lang)
if lang != original_lang:
    url_translation = "http://127.0.0.1:5003/translate"
    data = {
        "text": sentence,
        "source": original_lang,
        "target": lang
    }
    response = requests.post(url_translation, json=data)
    sentence=response.text

words = sentence.split()

# %%
sentence
# Out:
# 'Vous vous demandez comment les protéines affectent le taux de sucre dans le sang?'

# %%
original_lang
# Out:
# 'English'

# %%
lang
# Out:
# 'French'

# %%
import moviepy.config as cf

cf.change_settings({"IMAGEMAGICK_BINARY": "/opt/homebrew/bin/magick"})

# %%
import pandas as pd

metadata=pd.read_excel("metadata.xlsx")
metadata_image = metadata[metadata["type"] == 'image']
metadata_image = metadata_image[metadata_image["media_state"] == 'useful']

def find_image_for_term(term, metadata):
    url_datalake_paths = []
    metadata = metadata.dropna(subset=['keywords_description'])

    for idx, meta_row in metadata.iterrows():
        main_topic_stemmed = meta_row['main_topic']

        if term in main_topic_stemmed:
            url_datalake_paths.append(meta_row['path_datalake'])

    return url_datalake_paths

url_datalake_paths=find_image_for_term("food",metadata_image)

# %%
len(url_datalake_paths)
# Out:
# 189

# %%
import boto3
def put_image_in_s3(media,bucket_name,object_key):
    s3 = boto3.client('s3', aws_access_key_id="AKIAUJXLE2HEOGWEMCEX",aws_secret_access_key="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",region_name='eu-west-1')

    try:
        s3.put_object(Bucket=bucket_name, Key=object_key, Body=media)
        print("Media uploaded successfully to S3")
    except Exception as e:
        print(f"An error occurred: {e}")

file_path="metadata.xlsx"
excel_data = pd.read_excel(file_path)
        
# Convert DataFrame to Excel bytes
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    excel_data.to_excel(writer, index=False, header=True)

# Read the Excel file as bytes
with open(file_path, 'rb') as f:
    excel_bytes = f.read()

# Upload the file to S3 using the provided function
put_image_in_s3(excel_bytes, "soulchain-dev1-output-video", "metadata.xlsx")
# Out:
# Media uploaded successfully to S3

# %%
import boto3
import pandas as pd
from io import BytesIO
def read_metadata_from_s3(bucket_name, file_key):
    s3 = boto3.client('s3', aws_access_key_id="AKIAUJXLE2HEOGWEMCEX",aws_secret_access_key="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",region_name='eu-west-1')
    obj = s3.get_object(Bucket=bucket_name, Key=file_key)
    return pd.read_excel(BytesIO(obj['Body'].read()))

metadata=read_metadata_from_s3("soulchain-dev1-output-video", "metadata.xlsx")

# %%
metadata
# Out:
#       Unnamed: 0                          name  \
# 0              0         social-media-1360.mp4
# 1              1               woman-38084.mp4
# 2              2              woman-174003.mp4
# 3              3         iphone-160307_150.png
# 4              4  mobile-phone-1875813_150.jpg
# ...          ...                           ...
# 4501        5197     sunflower-3113318_150.jpg
# 4502        5198     sunflower-1627193_150.jpg
# 4503        5199          sunflowers-59483.mp4
# 4504        5200             squirrel-2717.mp4
# 4505        5201                 bird-9334.mp4
#
#                                                keywords  \
# 0             ['social media', 'smart phone', 'mobile']
# 1                      ['woman', 'phone', 'smartphone']
# 2                ['woman', 'social networking', 'post']
# 3                     ['iphone', 'cell phone', 'phone']
# 4     ['mobile phone', 'smartphone', 'hohenzollern c...
# ...
